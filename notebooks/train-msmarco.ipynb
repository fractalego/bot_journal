# %%
import json
import torch
import torch.nn as nn
import random
from tqdm import tqdm
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
dev_dict = json.load(open('../data/coqa-dev-v1.0.json', encoding='utf8'))

# %%
train_list = json.load(open('../data/qa_train_list.json', encoding='utf8'))
dev_list = json.load(open('../data/qa_dev_list.json', encoding='utf8'))

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def batchify(data, n):
    len_dict = {}
    for item in data:
        length = item.shape[1]
        try:
            len_dict[length].append(item)
        except:
            len_dict[length] = [item]

    batch_chunks = []
    for k in len_dict.keys():
        vectors = len_dict[k]
        batch_chunks += chunks(vectors, n)

    batches = []
    for chunk in batch_chunks:
        inputs = torch.stack([item[0] for item in chunk])
        batches.append((inputs))

    return batches

# %%
_limit = 1024
data = []
total_trimmed = 0
for item in train_list:
    tokens = tokenizer.encode(item, return_tensors='pt')
    if tokens.shape[1] > _limit:
        tokens = tokens[:, :_limit]
        total_trimmed += 1
    data.append(tokens)
print(f'Trimmed {total_trimmed} out of {len(train_list)}')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1088 > 1024). Running this sequence through the model will result in indexing errors
# Trimmed 52 out of 7199

# %%
train_batches = batchify(data, 1)

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')
model.cuda()
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5)

# %%
def train(train_model, batches, optimizer, criterion):
    total_loss = 0.
    for i, batch in tqdm(enumerate(batches), total=len(batches)):
        model.train()
        inputs = batch
        optimizer.zero_grad()
        loss = train_model(inputs.cuda(), labels=inputs.cuda())[0]
        loss.backward()
        torch.nn.utils.clip_grad_norm_(train_model.parameters(), 0.5)
        optimizer.step()
        total_loss += loss.item()

    return total_loss / len(batches)

def test(test_model, batches):
    total_loss = 0.
    for i, batch in tqdm(enumerate(batches), total=len(batches)):
        test_model.eval()
        inputs = batch
        loss = test_model(inputs, labels=inputs)[0]
        total_loss += loss.item()

    return total_loss / len(batches)

# %%
from torch.optim.lr_scheduler import StepLR

random.shuffle(train_batches)
scheduler = StepLR(optimizer, step_size=2, gamma=0.8)
for epoch in range(10):
    random.shuffle(train_batches)
    loss = train(model, train_batches, optimizer, criterion)
    print('Epoch:', epoch, 'Loss:', loss)
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict()},
                'save_small' + str(epoch))
    scheduler.step()

# %%
_question_prompt = '\nQ: '
_answer_prompt = '\nA: '
    
def get_text_up_to_question_number(text, number):
    pos = text.find(_answer_prompt)
    for _ in range(number):
        pos = text.find(_answer_prompt, pos + 1)
    return text[0:pos + 1]
    
def get_answers_number(text):
    return text.count(_answer_prompt)

def get_answer_number(text, number):
    pos = text.find(_answer_prompt)
    for _ in range(number):
        pos = text.find(_answer_prompt, pos + 1)
    end = text.find('\n', pos + len(_answer_prompt))
    return text[pos + len(_answer_prompt):end]

def get_question_number(text, number):
    pos = text.find(_question_prompt)
    for _ in range(number):
        pos = text.find(_question_prompt, pos + 1)
    end = text.find('\n', pos + len(_question_prompt))
    return text[pos + len(_question_prompt):end]

def get_all_answers(dev_dict, dev_index):
    answers = [[item['input_text'] for item in dev_dict['data'][dev_index]['answers']]]
    answers += [[item['input_text'] for item in dev_dict['data'][dev_index]['additional_answers'][str(index)]] for index in range(3)]
    return [list(set([answers[j][i] for j in range(len(answers))])) for i in range(len(answers[0]))]

# %%
def generate_answer_number(model, text, number):
    prompt = get_text_up_to_question_number(text, number)
    tokens = tokenizer.encode(prompt, return_tensors='pt')
    _length = 20
    tokens_length = tokens.shape[1]
    output = model.generate(
             tokens,
             max_length=tokens_length + _length,
             temperature=0,
             pad_token_id=50256
    )
    output = tokenizer.decode(output[0], skip_special_tokens=True)
    return get_answer_number(output, number)

# %%
def compute_accuracy_of_model_with_all_answers(model):
    total_number_of_questions = 0
    correct_answers = 0
    wrong_predictions = []

    dlist = dev_list[:10]
    for index, text in tqdm(enumerate(dlist), total=len(dlist)):
        total_questions = get_answers_number(text)
        all_answers = get_all_answers(dev_dict, index)
        for number in range(total_questions):
            prediction = generate_answer_number(model, text, number)
            prediction = prediction.replace('.', '').replace('"', '')
            it_was_answered = False
            for label in all_answers[number]:
                label = label.replace('.', '').replace('"', '')
                if prediction.lower() == label.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                elif prediction.lower() in label.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                elif label.lower() in prediction.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                else:
                    wrong_predictions.append({'label': label, 'prediction': prediction})
            if not it_was_answered:
                print('No Answer for number', number)
            total_number_of_questions += 1

    return correct_answers/total_number_of_questions, wrong_predictions

# %%
def get_text_from_data_item(item, max_num_questions=0, question_number=-1, last_question=True):
    text = 'In the text below two people are discussing a story.\n\n'
    text += 'Story:\n' + item['story'] + '\n\n'
    text += 'Discussion:\n'
    text += '\n'.join(['Q: ' + q['input_text'] 
                       + '\nA: ' + a['input_text'] 
                       for q, a in zip(item['questions'][max(0,question_number-max_num_questions):question_number+1], 
                                       item['answers'][max(0,question_number-max_num_questions):question_number+1]) 
                      ])
    if not last_question:
        text = '\n'.join(text.split('\n')[:-1]) + '\n'
    return text

# %%
def get_text_from_data_item_and_story(story, item, max_num_questions=0, question_number=-1, last_question=True):
    text = 'In the text below two people are discussing a story.\n\n'
    text += 'Story:\n' + story + '\n\n'
    text += 'Discussion:\n'
    text += '\n'.join(['Q: ' + q['input_text'] 
                       + '\nA: ' + a['input_text'] 
                       for q, a in zip(item['questions'][max(0,question_number-max_num_questions):question_number+1], 
                                       item['answers'][max(0,question_number-max_num_questions):question_number+1]) 
                      ])
    if not last_question:
        text = '\n'.join(text.split('\n')[:-1]) + '\n'
    return text

# %%
def generate_answer(model, prompt):
    tokens = tokenizer.encode(prompt, return_tensors='pt')
    _length = 50
    tokens_length = tokens.shape[1]
    if tokens_length + _length > 1024:
        return ''
    output = model.generate(
             tokens.cuda(),
             max_length=tokens_length + _length,
             #temperature=0,
             pad_token_id=50256
    )
    output = tokenizer.decode(output[0], skip_special_tokens=True)
    offset = len(prompt)
    start = offset + 1
    end = output.find('\n', start)
    return output[start:end].split(':')[-1].strip()

# %% [markdown]
# # Simplify text according to question

# %%
import re
from nltk.tokenize.texttiling import TextTilingTokenizer

# %%
def clean_chapter(text):
    text = re.sub("\[.*?\]", "", text)
    text = re.sub("\(.*?\)", "", text)
    return text

# %%
def get_chapters_from_nltk(text_file):
    tt = TextTilingTokenizer(w=1, k=2)
    paragraphs = tt.tokenize(text_file)
    paragraphs = [p.replace('\r\n', '\n') for p in paragraphs]
    paragraphs = [clean_chapter(p) for p in paragraphs]
    return paragraphs

# %%
from sentence_transformers import SentenceTransformer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sentence_model = SentenceTransformer('msmarco-distilbert-base-v3')
sentence_model = sentence_model.to(device)

# %%
from gensim.models import KeyedVectors

# %%
def get_embeddings_from_text(text):
    outputs = sentence_model.encode(text)
    return outputs

# %%
def get_sentence_retriever_from_text(text):
    retriever = KeyedVectors(768)
    
    try:
        sentences = get_chapters_from_nltk(text)
    except ValueError:
        embeddings = get_embeddings_from_text(text)
        retriever.add_vector(text, embeddings)
        return retriever
    for sentence in sentences:
        embeddings = get_embeddings_from_text(sentence)
        retriever.add_vector(sentence, embeddings)
        
    return retriever

# %%
def get_documents_and_scores(retriever, query):
    embeddings = get_embeddings_from_text(query)
    results = retriever.similar_by_vector(embeddings, topn=5)
    return results

# %%
def get_text_from_retriever(retriever, query):
    docs_and_scores = get_documents_and_scores(retriever, query)
    return '. '.join(item[0] for item in docs_and_scores).strip() + '.'

# %%
dev_dict['data'][0]['questions'][0]['input_text']
# Out:
# 'What color was Cotton?'

# %%
def get_text_for_index(index):
    return dev_dict['data'][index]['story']

def get_question_for_index_and_number(index, number):
    return dev_dict['data'][index]['questions'][number]['input_text']

# %%
retriever = get_sentence_retriever_from_text(get_text_for_index(0))

# %%
print(get_text_from_retriever(retriever, get_question_for_index_and_number(0, 0)))
# Out:
# Once upon a time, in a barn near a farm house, there lived a little white kitten named Cotton. Cotton lived high up in a nice warm place above the barn where all of the farmer's horses slept. But Cotton wasn't alone in her little home above the barn, oh no. She shared her hay bed with her mommy and 5 other sisters. All of her sisters were cute and fluffy, like Cotton. But she was the only white one in the bunch. The rest of her sisters were all orange with beautiful white tiger stripes like Cotton's mommy. Being different made Cotton quite sad. She often wished she looked like the rest of her family. So one day, when Cotton found a can of the old farmer's orange paint, she used it to paint herself like them. When her mommy and sisters found her they started laughing..
#
# "What are you doing, Cotton?!"
#
# "I only wanted to be more like you".
#
# Cotton's mommy rubbed her face on Cotton's and said "Oh Cotton, but your fur is so pretty and special, like you. We would never want you to be any other way". And with that, Cotton's mommy picked her up and dropped her into a big bucket of water. When Cotton came out she was herself again. Her sisters licked her face until Cotton's fur was all all dry..
#
# Then Cotton thought, "I change my mind. I like being special"..
#
# "Don't ever do that again, Cotton!" they all cried. "Next time you might mess up that pretty white fur of yours and we wouldn't want that!".

# %% [markdown]
# ## Actually test the model

# %%
def compute_accuracy_of_model(model):
    total_number_of_questions = 0
    correct_answers = 0
    wrong_predictions = []

    false_positives = []
    dlist = dev_list[:100]
    for index, text in tqdm(enumerate(dlist), total=len(dlist)):

        all_answers = get_all_answers(dev_dict, index)
        total_questions = len(all_answers)        
        
        for number in range(total_questions):
            retriever = get_sentence_retriever_from_text(get_text_for_index(index))
            story = get_text_from_retriever(retriever, get_question_for_index_and_number(index, number))
            small_text = get_text_from_data_item_and_story(story, dev_dict['data'][index],
                                     max_num_questions=5,
                                     question_number=number,
                                     last_question=False)
            #print(small_text)
            prediction = generate_answer(model, small_text)
            #print('prediction', prediction)
            if not prediction:
                print('NO PREDICTION!!')
                prediction = 'unknown'
            prediction = prediction.replace('.', '').replace('"', '')
            it_was_answered = False
            for label in all_answers[number]:
                label = label.replace('.', '').replace('"', '')

                if prediction.lower() != 'unknown' and label.lower() == 'unknown':
                    false_positives.append(prediction)
                
                if prediction.lower() == label.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                elif prediction.lower() in label.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                elif label.lower() in prediction.lower():
                    correct_answers += 1
                    it_was_answered = True
                    break
                else:
                    wrong_predictions.append({'label': label, 'prediction': prediction})
            total_number_of_questions += 1

    return correct_answers/total_number_of_questions, wrong_predictions, false_positives

# %%
false_positives = None
wrong_answers = None

for index in range(6,7):
    checkpoint = torch.load('save_small' + str(index))
    model.load_state_dict(checkpoint['model_state_dict'])
    accuracy, wrong_answers, false_positives = compute_accuracy_of_model(model.cuda())
    print('Epoch:', index, ' with accuracy:', accuracy)
# Out:
#   3%|▎         | 3/100 [00:18<10:36,  6.56s/it]
# NO PREDICTION!!
# NO PREDICTION!!
#  15%|█▌        | 15/100 [01:40<09:27,  6.68s/it]
# NO PREDICTION!!
# NO PREDICTION!!
#  27%|██▋       | 27/100 [03:18<11:00,  9.04s/it]
# NO PREDICTION!!
# 100%|██████████| 100/100 [12:23<00:00,  7.43s/it]
# Epoch: 6  with accuracy: 0.6866708780795957

# %%
wrong_answers
# Out:
# [{'label': "the old farmer's", 'prediction': 'her mommy'},
#  {'label': 'the farmer', 'prediction': 'her mommy'},
#  {'label': "the farmer's", 'prediction': 'her mommy'},
#  {'label': 'they started laughing', 'prediction': 'laughed'},
#  {'label': 'rubbed her face', 'prediction': 'laughed'},
#  {'label': 'started laughing', 'prediction': 'laughed'},
#  {'label': 'into a big bucket of water', 'prediction': 'a bucket of water'},
#  {'label': 'dropped her into a big bucket of water',
#   'prediction': 'a bucket of water'},
#  {'label': 'the bottle', 'prediction': 'It was hard and clear'},
#  {'label': 'a bottle', 'prediction': 'It was hard and clear'},
#  {'label': 'Sharkie', 'prediction': 'a friend'},
#  {'label': 'Asta', 'prediction': 'a friend'},
#  {'label': 'Asta', 'prediction': 'a friend'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': "They took the note to Asta's papa",
#   'prediction': "took it to Asta's papa"},
#  {'label': 'unknown', 'prediction': "took it to Asta's papa"},
#  {'label': "They took the note to Asta's papa",
#   'prediction': "took it to Asta's papa"},
#  {'label': 'unknown', 'prediction': 'Yes'},
#  {'label': 'an elderly Chinese lady', 'prediction': 'a Chinese lady'},
#  {'label': 'An elderly Chinese lady and a little boy',
#   'prediction': 'a Chinese lady'},
#  {'label': 'elderly Chinese lady', 'prediction': 'a Chinese lady'},
#  {'label': 'a little boy', 'prediction': 'Yes'},
#  {'label': 'a little boy', 'prediction': 'a paper carrier bag'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'her daughter bought the house next door', 'prediction': 'Nicole'},
#  {'label': 'next door', 'prediction': 'Shanghai'},
#  {'label': 'house next door', 'prediction': 'Shanghai'},
#  {'label': 'her brother', 'prediction': 'His grandmother'},
#  {'label': 'more nutrients',
#   'prediction': 'rice, vegetables and either chicken, meat or shrimp'},
#  {'label': 'needs more nutrients before heart surger',
#   'prediction': 'heart surgery'},
#  {'label': 'an iPad',
#   'prediction': 'a thermos with hot soup and a stainless-steel container with rice, vegetables and either chicken, meat or shrimp, sometimes with a kind of pancake'},
#  {'label': 'soup and a stainless-steel container with rice, vegetables and either chicken, meat or shrimp, sometimes with a kind of pancake',
#   'prediction': 'food'},
#  {'label': 'hot soup, rice, vegetables, chicken, meat, or shrimp, sometimes with a kind of pancake',
#   'prediction': 'food'},
#  {'label': 'hot soup and a container with rice, vegetables and either chicken, meat or shrimp, sometimes with a kind of pancake',
#   'prediction': 'food'},
#  {'label': 'rice, vegetables and either chicken, meat or shrimp, sometimes with a kind of pancake',
#   'prediction': 'food'},
#  {'label': 'Nicole',
#   'prediction': 'I point to the screen, which displayed a message from her daughter telling me that her mother wanted to know if the food was all right and whether it was too salty I am not used to iPads, so she indicated I should go wit'},
#  {'label': 'go with her to her house',
#   'prediction': 'I point to the screen, which displayed a message from her daughter telling me that her mother wanted to know if the food was all right and whether it was too salty I am not used to iPads, so she indicated I should go wit'},
#  {'label': 'I am now working on some more Chinese words',
#   'prediction': 'I point to the screen, which displayed a message from her daughter telling me that her mother wanted to know if the food was all right and whether it was too salty I am not used to iPads, so she indicated I should go wit'},
#  {'label': 'use the iPad',
#   'prediction': 'I point to the screen, which displayed a message from her daughter telling me that her mother wanted to know if the food was all right and whether it was too salty I am not used to iPads, so she indicated I should go wit'},
#  {'label': 'he was an actor', 'prediction': 'p-turned-actor'},
#  {'label': 'got into acting', 'prediction': 'was on Law & Order'},
#  {'label': 'Farina was cast in a film', 'prediction': 'was on Law & Order'},
#  {'label': 'he was a consultant', 'prediction': 'was on Law & Order'},
#  {'label': 'he got into acting', 'prediction': 'was on Law & Order'},
#  {'label': 'He joined a TV show cast',
#   'prediction': 'joined the cast of the long-running Law & Order'},
#  {'label': 'joined the cast of Law & Order',
#   'prediction': 'joined the cast of the long-running Law & Order'},
#  {'label': ', he joined the cast of Law & Order',
#   'prediction': 'joined the cast of the long-running Law & Order'},
#  {'label': 'he joined the cast of  Law & Order',
#   'prediction': 'joined the cast of the long-running Law & Order'},
#  {'label': 'no', 'prediction': 's'},
#  {'label': 'No', 'prediction': 's'},
#  {'label': 'no', 'prediction': 's'},
#  {'label': 'No', 'prediction': 's'},
#  {'label': 'A cop', 'prediction': 'lice officer'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'No', 'prediction': 'yes'},
#  {'label': 'they go in for cookies and milk',
#   'prediction': 'walk home from the bus stop'},
#  {'label': "go to Quentin's house",
#   'prediction': 'walk home from the bus stop'},
#  {'label': 'get cookies and milk',
#   'prediction': 'walk home from the bus stop'},
#  {'label': 'go in for cookies and milk',
#   'prediction': 'walk home from the bus stop'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'no one answered',
#   'prediction': 'she thought something might be wrong'},
#  {'label': 'no answer', 'prediction': 'she thought something might be wrong'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': "Quinton's mother", 'prediction': 'her mother'},
#  {'label': 'after lunch', 'prediction': 'tomorrow'},
#  {'label': 'yes', 'prediction': 'tomorrow'},
#  {'label': 'New York', 'prediction': 'New Jersey'},
#  {'label': 'New York', 'prediction': 'New Jersey'},
#  {'label': 'In the southwest of the city',
#   'prediction': 'the southernmost part of the island'},
#  {'label': 'southernmost part of both the city and state of New York',
#   'prediction': 'the southernmost part of the island'},
#  {'label': 'the southernmost part of both the city and state of New York',
#   'prediction': 'the southernmost part of the island'},
#  {'label': 'the Arthur Kill and the Kill Van Kull',
#   'prediction': 'Conference House Park'},
#  {'label': 'the Arthur Kill and the Kill Van Kull,',
#   'prediction': 'Conference House Park'},
#  {'label': 'Arthur Kill and the Kill Van Kull',
#   'prediction': 'Conference House Park'},
#  {'label': 'because the inhabitants feel neglected by the city government',
#   'prediction': 'by inhabitants who feel neglected by the city government'},
#  {'label': 'inhabitants feel neglected by the city government',
#   'prediction': 'by inhabitants who feel neglected by the city government'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'Eppes', 'prediction': 'Glass, wood, and plaster'},
#  {'label': 'the suspect', 'prediction': 'FBI agents'},
#  {'label': 'Gary Giordano', 'prediction': 'FBI agents'},
#  {'label': 'Maryland', 'prediction': 'Gaithersburg'},
#  {'label': 'Gaithersburg', 'prediction': 'Montgomery County'},
#  {'label': 'Maryland', 'prediction': 'Alabama'},
#  {'label': 'he is the suspect in the disappearance of an American woman',
#   'prediction': 'he is being held in an Aruban jail'},
#  {'label': 'he is a suspect in the recent disappearance of an American woman',
#   'prediction': 'he is being held in an Aruban jail'},
#  {'label': 'suspect in the recent disappearance of an American woman',
#   'prediction': 'he is being held in an Aruban jail'},
#  {'label': 'Giordano', 'prediction': 'Gardner'},
#  {'label': '2, Giordano told authorities that he had been snorkeling with Gardner',
#   'prediction': 'three days after Robyn Gardner was last seen'},
#  {'label': 'Two',
#   'prediction': 'three days after Robyn Gardner was last seen'},
#  {'label': 'Great Britain', 'prediction': 'India'},
#  {'label': 'Steam it',
#   'prediction': 'it lost nearly all of its healthy qualities'},
#  {'label': 'steam it',
#   'prediction': 'it lost nearly all of its healthy qualities'},
#  {'label': 'prune it',
#   'prediction': 'it lost nearly all of its healthy qualities'},
#  {'label': 'They steam it',
#   'prediction': 'it lost nearly all of its healthy qualities'},
#  {'label': 'It may prevent heart disease',
#   'prediction': 'prevents heart disease'},
#  {'label': 'may prevent heart disease',
#   'prediction': 'prevents heart disease'},
#  {'label': 'Prevent heart disease', 'prediction': 'prevents heart disease'},
#  {'label': 'may prevent heart disease',
#   'prediction': 'prevents heart disease'},
#  {'label': 'unknown', 'prediction': 'bad digestion'},
#  {'label': 'bloody',
#   'prediction': 'it was laid over a patch of sand and grass'},
#  {'label': 'two bodies propped up',
#   'prediction': 'soldiers kneeling by a bloody body sprawled over a patch of sand and grass'},
#  {'label': 'what appears to be two bodies propped up,',
#   'prediction': 'soldiers kneeling by a bloody body sprawled over a patch of sand and grass'},
#  {'label': 'propped up, back to back',
#   'prediction': 'soldiers kneeling by a bloody body sprawled over a patch of sand and grass'},
#  {'label': 'military vehicle', 'prediction': 'a post'},
#  {'label': 'a military vehicle', 'prediction': 'a post'},
#  {'label': 'in front of a military vehicle', 'prediction': 'a post'},
#  {'label': 'Holmes is charged with the premeditated deaths of three civilians',
#   'prediction': 'murder'},
#  {'label': 'the premeditated deaths of three civilians',
#   'prediction': 'murder'},
#  {'label': 'The premeditated deaths of three civilians, possessing a dismembered human finger, wrongfully possessing photographs of human casualties, and smoking hashish',
#   'prediction': 'murder'},
#  {'label': 'Floyd Mayweather and Manny Pacquiao',
#   'prediction': 'Sauerland and Pacquiao'},
#  {'label': '(The Best Ever)', 'prediction': 'e Money Man'},
#  {'label': 'The Best Ever', 'prediction': 'e Money Man'},
#  {'label': 'CEO', 'prediction': 'O of Team Sauerland'},
#  {'label': 'hope of a nation', 'prediction': 'he throws the money around'},
#  {'label': "he's the hope of a nation",
#   'prediction': 'he throws the money around'},
#  {'label': 'just that it has bible references and shows him enjoying gos[e; singing with his wife',
#   'prediction': 'he throws the money around'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'Ohio College', 'prediction': 'Ohio State University'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'He is not', 'prediction': 'Yes'},
#  {'label': 'treamline operations, control costs, and increase efficiency in library management',
#   'prediction': 'bring libraries together'},
#  {'label': 'increase efficiency in library management',
#   'prediction': 'bring libraries together'},
#  {'label': 'online cataloging', 'prediction': 'bring libraries together'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'Not during the story, but probably afterward',
#   'prediction': 'Yes'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'flowers', 'prediction': "Mother's birthday present"},
#  {'label': 'They bought flowers', 'prediction': "Mother's birthday present"},
#  {'label': 'Flowers', 'prediction': "Mother's birthday present"},
#  {'label': 'Looked like a big box', 'prediction': 'It looks like diamonds'},
#  {'label': "It doesn't look good", 'prediction': 'It looks like diamonds'},
#  {'label': "It didn't look good", 'prediction': 'It looks like diamonds'},
#  {'label': "It doesn't look good", 'prediction': 'It looks like diamonds'},
#  {'label': 'She already had two', 'prediction': "It's only $15"},
#  {'label': 'she already has two', 'prediction': "It's only $15"},
#  {'label': 'She already has two blouses', 'prediction': "It's only $15"},
#  {'label': 'At least $500', 'prediction': '$15'},
#  {'label': '$500', 'prediction': '$15'},
#  {'label': 'at least $500', 'prediction': '$15'},
#  {'label': 'his house', 'prediction': 'the water'},
#  {'label': 'climbed on', 'prediction': 'look at the water'},
#  {'label': 'got very wet', 'prediction': 'landed by the toy boat'},
#  {'label': 'came splashing into the water to fetch',
#   'prediction': 'landed by the toy boat'},
#  {'label': 'came splashing into the water to fetch it',
#   'prediction': 'landed by the toy boat'},
#  {'label': 'got very wet', 'prediction': 'landed by the toy boat'},
#  {'label': 'The hospital had been bombed', 'prediction': 'It had been bombed'},
#  {'label': 'it was bombed', 'prediction': 'It had been bombed'},
#  {'label': 'The hospital had been bombed', 'prediction': 'It had been bombed'},
#  {'label': 'unknown', 'prediction': 'Germany'},
#  {'label': 'unknown', 'prediction': 'Eastern'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'he settled down in a village',
#   'prediction': 'Go back to his home'},
#  {'label': 'settle down in a village fifty miles',
#   'prediction': 'Go back to his home'},
#  {'label': 'settled in a village fifty miles away',
#   'prediction': 'Go back to his home'},
#  {'label': 'Hans settled down in a village fifty miles away',
#   'prediction': 'Go back to his home'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes, for twenty years', 'prediction': 'No'},
#  {'label': 'a workman', 'prediction': 'A taxi-driver'},
#  {'label': 'workman', 'prediction': 'A taxi-driver'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes, Franz does', 'prediction': 'No'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'He thought his brother had been killed in action',
#   'prediction': 'He was thought to have been killed in action during the war'},
#  {'label': 'Franz thought his brother was dead',
#   'prediction': 'He was thought to have been killed in action during the war'},
#  {'label': 'He assumed Hans was dead',
#   'prediction': 'He was thought to have been killed in action during the war'},
#  {'label': 'thought he was killed',
#   'prediction': 'He was thought to have been killed in action during the war'},
#  {'label': 'Mrs Bussman', 'prediction': 'A workman'},
#  {'label': "Franz' wife", 'prediction': 'A workman'},
#  {'label': 'Mrs Busman', 'prediction': 'A workman'},
#  {'label': 'he laughed at the idea',
#   'prediction': 'He thought there was a chance in a million that he might be his brother'},
#  {'label': 'Franz laughed',
#   'prediction': 'He thought there was a chance in a million that he might be his brother'},
#  {'label': 'Franz laughed at the idea',
#   'prediction': 'He thought there was a chance in a million that he might be his brother'},
#  {'label': 'the _Arie', 'prediction': 'rd'},
#  {'label': 'The Ariel', 'prediction': 'rd'},
#  {'label': 'Ariel', 'prediction': 'rd'},
#  {'label': 'The _Ariel_', 'prediction': 'rd'},
#  {'label': 'A lagoon', 'prediction': 'riel'},
#  {'label': 'lagoon', 'prediction': 'riel'},
#  {'label': 'Lagoon', 'prediction': 'riel'},
#  {'label': 'No', 'prediction': 'What was the name of the lagoon?'},
#  {'label': 'no', 'prediction': 'What was the name of the lagoon?'},
#  {'label': 'No', 'prediction': 'What was the name of the lagoon?'},
#  {'label': 'Captain Winters', 'prediction': 'ggs'},
#  {'label': 'Captain Winters', 'prediction': 'ggs'},
#  {'label': 'Winters', 'prediction': 'ggs'},
#  {'label': 'No', 'prediction': 'What color was it?'},
#  {'label': 'no', 'prediction': 'What color was it?'},
#  {'label': 'No', 'prediction': 'What color was it?'},
#  {'label': 'No',
#   'prediction': 'What was the name of the vessel they were on?'},
#  {'label': 'no',
#   'prediction': 'What was the name of the vessel they were on?'},
#  {'label': 'No',
#   'prediction': 'What was the name of the vessel they were on?'},
#  {'label': 'Harley Kennan', 'prediction': 'What was his original name?'},
#  {'label': 'Harley Kennan', 'prediction': 'What was his original name?'},
#  {'label': 'Harley', 'prediction': 'What was his original name?'},
#  {'label': 'Villa', 'prediction': "What was her husband's name?"},
#  {'label': 'Villa Kennan', 'prediction': "What was her husband's name?"},
#  {'label': 'The Arangi', 'prediction': 'rangi_'},
#  {'label': 'The Arangi', 'prediction': 'rangi_'},
#  {'label': 'Arangi', 'prediction': 'rangi_'},
#  {'label': 'Until they get back to Tulagi',
#   'prediction': 'e get back to Tulagi'},
#  {'label': "Harley Kennan'", 'prediction': 'ggs'},
#  {'label': 'Harley Kennan', 'prediction': 'ggs'},
#  {'label': 'Harley Kennan', 'prediction': 'ggs'},
#  {'label': 'Harley', 'prediction': 'ggs'},
#  {'label': 'No', 'prediction': 'hat did she call him?'},
#  {'label': 'no', 'prediction': 'hat did she call him?'},
#  {'label': 'No', 'prediction': 'hat did she call him?'},
#  {'label': "'Topsy'", 'prediction': "iselle de Maupin,'"},
#  {'label': 'Mademoiselle de Maupin', 'prediction': "iselle de Maupin,'"},
#  {'label': 'Judas', 'prediction': "iselle de Maupin,'"},
#  {'label': "'Mademoiselle de Maupin,", 'prediction': "iselle de Maupin,'"},
#  {'label': 'No', 'prediction': 'hat did she ask him to think of her?'},
#  {'label': 'no', 'prediction': 'hat did she ask him to think of her?'},
#  {'label': 'No', 'prediction': 'hat did she ask him to think of her?'},
#  {'label': 'Yes', 'prediction': 'What was it?'},
#  {'label': 'yes', 'prediction': 'What was it?'},
#  {'label': 'Yes', 'prediction': 'What was it?'},
#  {'label': 'unknown', 'prediction': 'What was the name of the island?'},
#  {'label': 'yes', 'prediction': 'What was the name of the island?'},
#  {'label': 'Ted', 'prediction': 'his family'},
#  {'label': 'a family', 'prediction': 'his family'},
#  {'label': 'Ted,', 'prediction': 'his family'},
#  {'label': 'a spot half a mile from the house',
#   'prediction': 'a deserted spot half a mile from the house'},
#  {'label': 'brought him food',
#   'prediction': "led Brownie's human owner to his trapped friend"},
#  {'label': 'stayed with Brownie to protect him from hunger',
#   'prediction': "led Brownie's human owner to his trapped friend"},
#  {'label': 'Brought him food',
#   'prediction': "led Brownie's human owner to his trapped friend"},
#  {'label': 'protect him from other dangers',
#   'prediction': 'kept him alive by sacrificing his own comfort'},
#  {'label': 'brought food',
#   'prediction': 'kept him alive by sacrificing his own comfort'},
#  {'label': 'stayed with Brownie to protect him from hunger and other dangers',
#   'prediction': 'kept him alive by sacrificing his own comfort'},
#  {'label': 'keep his spirits up',
#   'prediction': 'kept him alive by sacrificing his own comfort'},
#  {'label': 'keep his spirits up', 'prediction': 'kept his spirits up'},
#  {'label': 'keep his spirits up', 'prediction': 'kept his spirits up'},
#  {'label': 'protect him from other dangers',
#   'prediction': 'kept his spirits up'},
#  {'label': 'bakred', 'prediction': 'he followed Ted around'},
#  {'label': 'barked insistently', 'prediction': 'he followed Ted around'},
#  {'label': 'Barking', 'prediction': 'he followed Ted around'},
#  {'label': ' Spotty followed Ted about, barking insistently,',
#   'prediction': 'he followed Ted around'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'They were busy with their own lives,',
#   'prediction': 'he was still missing'},
#  {'label': 'They were busy with their own lives',
#   'prediction': 'he was still missing'},
#  {'label': 'they were busy with their own lives',
#   'prediction': 'he was still missing'},
#  {'label': 'They were busy', 'prediction': 'he was still missing'},
#  {'label': 'they went into the woods', 'prediction': 'Going into the woods'},
#  {'label': 'set out a trip', 'prediction': 'Going into the woods'},
#  {'label': 'Set on on a trip', 'prediction': 'Going into the woods'},
#  {'label': 'Going on a trip', 'prediction': 'Going into the woods'},
#  {'label': "He wasn't", 'prediction': 'interested'},
#  {'label': 'a bear', 'prediction': 'a brown bear'},
#  {'label': 'small brown bear', 'prediction': 'a brown bear'},
#  {'label': 'Small brown bear', 'prediction': 'a brown bear'},
#  {'label': 'Looked at the girl', 'prediction': 'resting in the bushes'},
#  {'label': 'rested in the bushes', 'prediction': 'resting in the bushes'},
#  {'label': 'looked up at the girl', 'prediction': 'resting in the bushes'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'confused', 'prediction': 'very interested'},
#  {'label': 'Surprised', 'prediction': 'very interested'},
#  {'label': 'surprised', 'prediction': 'very interested'},
#  {'label': 'looked up at the girl and it was almost as if he was smiling at her',
#   'prediction': 'rested his head on his bear paws'},
#  {'label': 'went back to sleep',
#   'prediction': 'rested his head on his bear paws'},
#  {'label': 'looked up at the girl',
#   'prediction': 'rested his head on his bear paws'},
#  {'label': 'Looked at the girl',
#   'prediction': 'rested his head on his bear paws'},
#  {'label': 'Nobody', 'prediction': 'A dog'},
#  {'label': 'no one', 'prediction': 'A dog'},
#  {'label': 'noone', 'prediction': 'A dog'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'A boy shot his father',
#   'prediction': 'A 10-year-old boy fatally shot his father'},
#  {'label': 'A boy fatally shot his father Friday',
#   'prediction': 'A 10-year-old boy fatally shot his father'},
#  {'label': 'a SUV', 'prediction': "his mother's home"},
#  {'label': '1700 block of Cedar Cove Court',
#   'prediction': "his mother's home"},
#  {'label': 'the front seat of a SUV', 'prediction': "his mother's home"},
#  {'label': 'in the front seat of a SUV', 'prediction': "his mother's home"},
#  {'label': "outside the home of Lohstroh's ex-wife",
#   'prediction': "in the back seat of the man's Toyota 4-Runner"},
#  {'label': "the home of Lohstroh's ex-wife",
#   'prediction': "in the back seat of the man's Toyota 4-Runner"},
#  {'label': "his mother's home",
#   'prediction': "in the back seat of the man's Toyota 4-Runner"},
#  {'label': 'about 3pm', 'prediction': 'Friday'},
#  {'label': 'still in the home', 'prediction': 'in the neighborhood'},
#  {'label': 'inside the house', 'prediction': 'in the neighborhood'},
#  {'label': 'the boy', 'prediction': 'his ex-wife'},
#  {'label': '7-year-old brother', 'prediction': 'his ex-wife'},
#  {'label': 'a 7-year-old brother', 'prediction': 'his ex-wife'},
#  {'label': 'the 7-year-old', 'prediction': 'his ex-wife'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'No', 'prediction': 'yes'},
#  {'label': 'the energy with which he sought to make the Christian life a reality',
#   'prediction': 'he owed his transcendent moral life to Fra Girolamo'},
#  {'label': 'he sought to make the Christian life a reality',
#   'prediction': 'he owed his transcendent moral life to Fra Girolamo'},
#  {'label': 'unknown',
#   'prediction': 'he owed his transcendent moral life to Fra Girolamo'},
#  {'label': 'For the energy with which he sought to make the Christian life a reality',
#   'prediction': 'he owed his transcendent moral life to Fra Girolamo'},
#  {'label': 'to witness the scene', 'prediction': 'sympathy'},
#  {'label': 'A source of strength/', 'prediction': 'sympathy'},
#  {'label': 'a sign from Baldassarre', 'prediction': 'sympathy'},
#  {'label': 'sympathy with Savonarola', 'prediction': 'a document'},
#  {'label': 'a revelation of the suspected conspiracy',
#   'prediction': 'a document'},
#  {'label': 'revelation of the suspected conspiracy',
#   'prediction': 'a document'},
#  {'label': 'the spreading Plague', 'prediction': 'sunny days'},
#  {'label': 'the spreading Plague and the Excommunication of Savonarola',
#   'prediction': 'sunny days'},
#  {'label': 'Plague', 'prediction': 'sunny days'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'Seattle', 'prediction': 'in a small apartment'},
#  {'label': 'Seattle', 'prediction': 'in a small apartment'},
#  {'label': 'in Seattle', 'prediction': 'in a small apartment'},
#  {'label': 'Two', 'prediction': 'three'},
#  {'label': 'One', 'prediction': 'three'},
#  {'label': 'the truck', 'prediction': 'a truck'},
#  {'label': 'the large truck', 'prediction': 'a truck'},
#  {'label': "Jenny's mom", 'prediction': 'her dad'},
#  {'label': "Jenny's dad", 'prediction': 'her dad'},
#  {'label': 'her mom', 'prediction': 'her dad'},
#  {'label': 'she liked it', 'prediction': 'sad'},
#  {'label': 'Jenny was going to like Utah', 'prediction': 'sad'},
#  {'label': 'She was going to like Utah!', 'prediction': 'sad'},
#  {'label': 'liked it', 'prediction': 'sad'},
#  {'label': 'injuries', 'prediction': 'skiing accident'},
#  {'label': 'ski accident', 'prediction': 'skiing accident'},
#  {'label': "She  fell on a beginners' slope", 'prediction': 'skiing accident'},
#  {'label': 'a ski accident', 'prediction': 'skiing accident'},
#  {'label': 'A local hospital', 'prediction': 'Lenox Hill Hospital'},
#  {'label': 'local hospital', 'prediction': 'Lenox Hill Hospital'},
#  {'label': 'a local hospital', 'prediction': 'Lenox Hill Hospital'},
#  {'label': 'Hopital du Sacre-Coeur', 'prediction': 'New York City'},
#  {'label': 'New York City', 'prediction': 'Lenox Hill Hospital'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'sons', 'prediction': 'Boys'},
#  {'label': 'Sons', 'prediction': 'Boys'},
#  {'label': 'the Tony', 'prediction': 'Tony-winning stage actress'},
#  {'label': 'Acting', 'prediction': 'She was a film star'},
#  {'label': 'acting', 'prediction': 'She was a film star'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'No', 'prediction': 'yes'},
#  {'label': 'fell right to sleep', 'prediction': 'held him in her arms'},
#  {'label': 'Fell asleep', 'prediction': 'held him in her arms'},
#  {'label': 'sleep', 'prediction': 'held him in her arms'},
#  {'label': 'made lots of fun memories', 'prediction': 'held him in her arms'},
#  {'label': 'an alien dog', 'prediction': 'a cute alien dog'},
#  {'label': 'Movie', 'prediction': 'in CJ7'},
#  {'label': 'a movie', 'prediction': 'in CJ7'},
#  {'label': 'Ti and his son', 'prediction': 'Dicky'},
#  {'label': 'Ti and his son', 'prediction': 'Dicky'},
#  {'label': 'Ti', 'prediction': 'Dicky'},
#  {'label': 'False', 'prediction': 'True'},
#  {'label': 'false', 'prediction': 'True'},
#  {'label': 'around his neck', 'prediction': 'in the trash'},
#  {'label': 'Around his neck', 'prediction': 'in the trash'},
#  {'label': 'round his neck', 'prediction': 'in the trash'},
#  {'label': 'Finds it in the trash', 'prediction': 'e gave it to him'},
#  {'label': 'he found it in the trash', 'prediction': 'e gave it to him'},
#  {'label': 'he finds it in the trash', 'prediction': 'e gave it to him'},
#  {'label': 'finds in the trash', 'prediction': 'e gave it to him'},
#  {'label': 'arts-and-crafts', 'prediction': 'art and crafts'},
#  {'label': "she's a stay-at-home mom", 'prediction': 'stay at home mom'},
#  {'label': 'stay-at-home', 'prediction': 'stay at home mom'},
#  {'label': 'Stay-at-home mom', 'prediction': 'stay at home mom'},
#  {'label': 'file the e-mail in a folder', 'prediction': 'by copying the link'},
#  {'label': 'File the email in a folder', 'prediction': 'by copying the link'},
#  {'label': 'copying the link, pasting it into an e-mail and sending it to herself',
#   'prediction': 'by copying the link'},
#  {'label': 'emailing it to herself',
#   'prediction': 'pasting it into an e-mail'},
#  {'label': 'Paste it in to an email to herself',
#   'prediction': 'pasting it into an e-mail'},
#  {'label': 'Its an an online filing system',
#   'prediction': 'a shared color board'},
#  {'label': 'it as an online filing system',
#   'prediction': 'a shared color board'},
#  {'label': 'she could pin costume ideas',
#   'prediction': 'a shared color board'},
#  {'label': 'the filing system', 'prediction': 'a shared color board'},
#  {'label': 'A shared color board', 'prediction': 'pinning away and'},
#  {'label': 'a shared color board', 'prediction': 'pinning away and'},
#  {'label': "a shared color board for redecorating her daughter's bedroom",
#   'prediction': 'pinning away and'},
#  {'label': "follow other's boards",
#   'prediction': "follow each other's boards"},
#  {'label': 'Following and re-pinning others boards',
#   'prediction': "follow each other's boards"},
#  {'label': 'yes', 'prediction': 're-pin'},
#  {'label': 'the third day', 'prediction': 'Three'},
#  {'label': 'Search for Bruce',
#   'prediction': 'To prepare to start with the hound'},
#  {'label': 'Reluctant', 'prediction': 'Aggressive'},
#  {'label': 'Hector', 'prediction': 'the Hound'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'Too many mounted men',
#   'prediction': 'because there were so many mounted men in the party'},
#  {'label': 'a bay', 'prediction': 'A loud deep bay'},
#  {'label': 'the armed forces', 'prediction': "the president's office"},
#  {'label': 'armed forces', 'prediction': "the president's office"},
#  {'label': 'military commanders', 'prediction': 'the top brass'},
#  {'label': 'new top military commanders', 'prediction': 'the top brass'},
#  {'label': 'top military commanders', 'prediction': 'the top brass'},
#  {'label': 'Brig Gen Bartolome Ramon Pineda Ortiz',
#   'prediction': 'Brig Gen Hugo Gilberto Aranda Chamorro and Rear Adm Egberto Emerito Orie Benegas'},
#  {'label': 'Bartolome Ramon Pineda Ortiz',
#   'prediction': 'Brig Gen Hugo Gilberto Aranda Chamorro and Rear Adm Egberto Emerito Orie Benegas'},
#  {'label': 'Cibar Benitez',
#   'prediction': 'Brig Gen Hugo Gilberto Aranda Chamorro and Rear Adm Egberto Emerito Orie Benegas'},
#  {'label': 'Rear Adm Egberto Emerito Orie Benegas',
#   'prediction': 'Hugo Gilberto Aranda Chamorro'},
#  {'label': 'Orie Benegas', 'prediction': 'Hugo Gilberto Aranda Chamorro'},
#  {'label': 'Catholic bishop', 'prediction': 'priest'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'No', 'prediction': 'es'},
#  {'label': 'no', 'prediction': 'es'},
#  {'label': 'No', 'prediction': 'es'},
#  {'label': 'yes', 'prediction': 'unknown'},
#  {'label': 'Yes', 'prediction': 'unknown'},
#  {'label': 'yes', 'prediction': 'what did they buy instead?'},
#  {'label': 'Yes', 'prediction': 'what did they buy instead?'},
#  {'label': 'theyd went to more stores', 'prediction': 'ht steaks'},
#  {'label': 'went to more stores to shop', 'prediction': 'ht steaks'},
#  {'label': 'MOre stores to shop', 'prediction': 'ht steaks'},
#  {'label': 'Hertfordshire', 'prediction': 'Bedfordshire'},
#  {'label': 'London commuter belt', 'prediction': 'a commuter belt'},
#  {'label': 'towns', 'prediction': 'a commuter belt'},
#  {'label': 'the London commuter belt', 'prediction': 'a commuter belt'},
#  {'label': 'parts of the London commuter belt',
#   'prediction': 'a commuter belt'},
#  {'label': 'Development', 'prediction': 'Metropolitan Green Belt'},
#  {'label': 'Philip', 'prediction': 'Pierre'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'Any news', 'prediction': 'a party'},
#  {'label': 'For carrying the news to them, should he pass through',
#   'prediction': 'a party'},
#  {'label': 'to any who would carry the news to them,',
#   'prediction': 'a party'},
#  {'label': 'for carrying  the news to them', 'prediction': 'a party'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': "not to say she'd spoken to him",
#   'prediction': 'that he wished to speak to him'},
#  {'label': 'She spoke to him', 'prediction': 'that he wished to speak to him'},
#  {'label': 'Speeking to him', 'prediction': 'that he wished to speak to him'},
#  {'label': 'that she has spoken to him',
#   'prediction': 'that he wished to speak to him'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'in the 9th century', 'prediction': 'Wiltunscir'},
#  {'label': 'Wilton', 'prediction': 'Wiltunscir'},
#  {'label': 'Stonehenge and Avebury stone circles',
#   'prediction': 'its mediaeval cathedral'},
#  {'label': 'Stonehenge and Avebury', 'prediction': 'Salisbury Plain'},
#  {'label': 'the Danes invaded the county',
#   'prediction': 'large areas of the country came into the possession of the crown and the church'},
#  {'label': 'Danes invaded the county',
#   'prediction': 'large areas of the country came into the possession of the crown and the church'},
#  {'label': "Marsha's noodle friend", 'prediction': 'A noodle friend'},
#  {'label': 'a piece of spaghetti', 'prediction': 'A noodle friend'},
#  {'label': 'A piece of spaghetti', 'prediction': 'A noodle friend'},
#  {'label': 'Marsha', 'prediction': 'Joey'},
#  {'label': 'Marsha', 'prediction': 'Joey'},
#  {'label': 'for dinner', 'prediction': 'To play with her noodle friend'},
#  {'label': 'It was spaghetti night',
#   'prediction': 'To play with her noodle friend'},
#  {'label': 'it was spaghetti night',
#   'prediction': 'To play with her noodle friend'},
#  {'label': 'For spaghetti night',
#   'prediction': 'To play with her noodle friend'},
#  {'label': 'Tuesday night', 'prediction': 'On Tuesday'},
#  {'label': 'A plastic bag', 'prediction': "Marsha's favorite dinner"},
#  {'label': 'in a plastic bag', 'prediction': "Marsha's favorite dinner"},
#  {'label': 'in a plastic bag in her pocket',
#   'prediction': "Marsha's favorite dinner"},
#  {'label': 'In a plastic bag in her pocket',
#   'prediction': "Marsha's favorite dinner"},
#  {'label': 'the constant thought of the grief and horror',
#   'prediction': 'disappointment'},
#  {'label': 'grief', 'prediction': 'disappointment'},
#  {'label': 'grief and horror', 'prediction': 'disappointment'},
#  {'label': 'separate', 'prediction': 'with the guests of royalty'},
#  {'label': 'Church', 'prediction': 'her companions'},
#  {'label': 'the Church', 'prediction': 'her companions'},
#  {'label': 'her Church', 'prediction': 'her companions'},
#  {'label': 'Jane Humphreys', 'prediction': 'Hester Bridgeman'},
#  {'label': 'silly', 'prediction': 'serious'},
#  {'label': 'four', 'prediction': 'Three'},
#  {'label': 'Hester Bridgeman', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'an attorney', 'prediction': 'Madam'},
#  {'label': 'an attorney in the city,', 'prediction': 'Madam'},
#  {'label': 'an attorney in the city', 'prediction': 'Madam'},
#  {'label': 'Tom', 'prediction': 'William Philander'},
#  {'label': 'William', 'prediction': 'Stanley'},
#  {'label': 'William Philander', 'prediction': 'Stanley'},
#  {'label': 'Spud', 'prediction': 'Stanley'},
#  {'label': 'Sam', 'prediction': 'Stanley'},
#  {'label': 'What Tom did to William', 'prediction': 'What did you do to him?'},
#  {'label': 'some other ads in his text books',
#   'prediction': 'put an advertisement of pills on his back'},
#  {'label': 'and some other ads in his text books',
#   'prediction': 'put an advertisement of pills on his back'},
#  {'label': 'Put other ads in his text books',
#   'prediction': 'put an advertisement of pills on his back'},
#  {'label': 'approaching', 'prediction': 'shaking his other fist'},
#  {'label': 'shaking his first', 'prediction': 'shaking his other fist'},
#  {'label': 'approaching with long strides',
#   'prediction': 'shaking his other fist'},
#  {'label': 'He was approaching with long strides',
#   'prediction': 'shaking his other fist'},
#  {'label': 'and he was shaking his other fist wrathfully',
#   'prediction': 'holding the poster Tom had fastened on his back'},
#  {'label': 'shaking his fist',
#   'prediction': 'holding the poster Tom had fastened on his back'},
#  {'label': 'he was shaking his other fist wrathfully',
#   'prediction': 'holding the poster Tom had fastened on his back'},
#  {'label': 'shaking his other fist',
#   'prediction': 'holding the poster Tom had fastened on his back'},
#  {'label': 'was so full of wrath',
#   'prediction': "Tom Rover, you've humiliated me before the whole class! I'll--I'll----"},
#  {'label': 'he was so full of wrath he could not speak',
#   'prediction': "Tom Rover, you've humiliated me before the whole class! I'll--I'll----"},
#  {'label': 'he was too angry',
#   'prediction': "Tom Rover, you've humiliated me before the whole class! I'll--I'll----"},
#  {'label': 'He was so full of wrath he could not speak',
#   'prediction': "Tom Rover, you've humiliated me before the whole class! I'll--I'll----"},
#  {'label': "Tom Rover, you've--er--insulted me!",
#   'prediction': 'Take a cough drop and clear your throat Billy'},
#  {'label': "Tom Rover, you've--er--insulted me!",
#   'prediction': 'Take a cough drop and clear your throat Billy'},
#  {'label': "'Gumley's Red Pills for Red-Blooded People,'",
#   'prediction': "They are fine, Willie Didn't you ever take 'em?"},
#  {'label': 'for Red-Blooded People',
#   'prediction': "They are fine, Willie Didn't you ever take 'em?"},
#  {'label': 'that they were for Red-Blooded People',
#   'prediction': "They are fine, Willie Didn't you ever take 'em?"},
#  {'label': "they're for Red-Blooded People",
#   'prediction': "They are fine, Willie Didn't you ever take 'em?"},
#  {'label': 'He was flat on his back with half a dozen fatal diseases',
#   'prediction': 'He was nearly died'},
#  {'label': 'got up and went to work', 'prediction': 'He was nearly died'},
#  {'label': 'He got better', 'prediction': 'He was nearly died'},
#  {'label': 'he was flat on his back with half a dozen fatal diseases',
#   'prediction': 'He was nearly died'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'Eight', 'prediction': '8'},
#  {'label': '7 girl cats and only 1 boy cat', 'prediction': 'One'},
#  {'label': 'Seven', 'prediction': 'One'},
#  {'label': 'Three', 'prediction': '3'},
#  {'label': 'orange, black, spotted, and white',
#   'prediction': 'orange, black, and spotted'},
#  {'label': 'Orange, black, spotted, and white',
#   'prediction': 'orange, black, and spotted'},
#  {'label': 'Some are orange', 'prediction': 'orange, black, and spotted'},
#  {'label': 'Some are orange and some black',
#   'prediction': 'orange, black, and spotted'},
#  {'label': 'The white cat', 'prediction': 'Snowball'},
#  {'label': 'the white cat', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'female', 'prediction': 'Snowball'},
#  {'label': 'none', 'prediction': 'Three'},
#  {'label': 'None', 'prediction': 'Three'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'Sneaking idea', 'prediction': "He's afraid"},
#  {'label': 'He has a sneaking idea', 'prediction': "He's afraid"},
#  {'label': 'he has a sneaking idea it is good', 'prediction': "He's afraid"},
#  {'label': 'a sneaking idea', 'prediction': "He's afraid"},
#  {'label': 'To Ruth', 'prediction': 'Martin'},
#  {'label': 'Ruth', 'prediction': 'Martin'},
#  {'label': 'to make certain whether or not he would be at their table',
#   'prediction': 'To see if he would be at their table'},
#  {'label': 'About Thanksgiving dinner',
#   'prediction': 'To see if he would be at their table'},
#  {'label': 'to see if he would be at Thanksgiving dinner',
#   'prediction': 'To see if he would be at their table'},
#  {'label': 'To see whether he is coming for Thanksgiving',
#   'prediction': 'To see if he would be at their table'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'Arthur', 'prediction': 'Yes'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'Arthur', 'prediction': 'Martin'},
#  {'label': 'WIth Arthur', 'prediction': 'Martin'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'Too strong for magazines',
#   'prediction': "Because he knows they won't sell"},
#  {'label': "It's too strong for the magazines",
#   'prediction': "Because he knows they won't sell"},
#  {'label': "It's too strong",
#   'prediction': "Because he knows they won't sell"},
#  {'label': 'he was concussed', 'prediction': 'because of a high impact'},
#  {'label': 'Returning to racing three weeks after a high impact was too risky',
#   'prediction': 'because of a high impact'},
#  {'label': 'injured in a traing crash',
#   'prediction': 'because of a high impact'},
#  {'label': 'a freak accident', 'prediction': 'because of a high impact'},
#  {'label': 'unpredictably gusty winds', 'prediction': 'high speed crash'},
#  {'label': 'a freak accident', 'prediction': 'high speed crash'},
#  {'label': 'gusty winds on the track', 'prediction': 'high speed crash'},
#  {'label': 'Lost control of his McLaren', 'prediction': 'high speed crash'},
#  {'label': 'Wednesday', 'prediction': 'February 22'},
#  {'label': 'his comeback', 'prediction': 'return to racing'},
#  {'label': 'His comeback at the Malaysian Grand Prix',
#   'prediction': 'return to racing'},
#  {'label': 'comeback at Malaysian GP', 'prediction': 'return to racing'},
#  {'label': 'practicing qualifying and race procedures',
#   'prediction': 'return to racing'},
#  {'label': 'Lewis Hamilton', 'prediction': 'Fernando Alonso'},
#  {'label': 'Woking, England', 'prediction': 'McLaren'},
#  {'label': 'Woking, England', 'prediction': 'McLaren'},
#  {'label': 'Ben, Johnny, and Paul', 'prediction': 'Ben and Johnny'},
#  {'label': 'Paul', 'prediction': 'Ben and Johnny'},
#  {'label': 'of the street', 'prediction': 'a suspicious sort of a person'},
#  {'label': 'Street', 'prediction': 'a suspicious sort of a person'},
#  {'label': 'slang of the street',
#   'prediction': 'a suspicious sort of a person'},
#  {'label': 'three meals a day', 'prediction': "Master Spry's misfortune"},
#  {'label': 'they had engaged rooms at a regular boarding-house',
#   'prediction': "Master Spry's misfortune"},
#  {'label': 'start a regular theatre',
#   'prediction': "Master Spry's misfortune"},
#  {'label': 'engage rooms at a regular boarding-house',
#   'prediction': "Master Spry's misfortune"},
#  {'label': 'they were to spend their substance on three square meals each day,',
#   'prediction': 'no'},
#  {'label': 'rooms at a regular boarding house', 'prediction': 'no'},
#  {'label': 'spend their substance on three square meals each day',
#   'prediction': 'no'},
#  {'label': 'they were to pay for three square meals each day',
#   'prediction': 'no'},
#  {'label': 'that they were to start a regular theatre',
#   'prediction': "Master Spry's misfortune"},
#  {'label': 'unknown', 'prediction': "Master Spry's misfortune"},
#  {'label': 'most exciting topic',
#   'prediction': 'as a reckless disregard of money'},
#  {'label': 'That it was wonderful news',
#   'prediction': 'as a reckless disregard of money'},
#  {'label': 'They were shaken by it',
#   'prediction': 'as a reckless disregard of money'},
#  {'label': 'It was wonderful',
#   'prediction': 'as a reckless disregard of money'},
#  {'label': 'They whispered', 'prediction': 'By talking'},
#  {'label': 'whispered from one to the other', 'prediction': 'By talking'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'already engaged a hall,',
#   'prediction': 'told him that they were to start a regular theatre'},
#  {'label': 'He already got a hall',
#   'prediction': 'told him that they were to start a regular theatre'},
#  {'label': 'he had already engaged a hall',
#   'prediction': 'told him that they were to start a regular theatre'},
#  {'label': 'had already engaged a hall,',
#   'prediction': 'told him that they were to start a regular theatre'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'it was going to be converted', 'prediction': 'yes'},
#  {'label': 'converted into a first-class place of amusement',
#   'prediction': 'yes'},
#  {'label': 'it would be converted into a first-class place of amusement',
#   'prediction': 'it would be regarded simply as a rumor'},
#  {'label': 'It was going to be converted',
#   'prediction': 'it would be regarded simply as a rumor'},
#  {'label': 'converted into a first-class place of amusement',
#   'prediction': 'it would be regarded simply as a rumor'},
#  {'label': 'Because of who was involved', 'prediction': 'it must be true'},
#  {'label': 'Did not come so directly from one of the parties concerned',
#   'prediction': 'it must be true'},
#  {'label': 'it had come directly from one of the parties concerned',
#   'prediction': 'it must be true'},
#  {'label': 'Because it came directly from one of the parties concerned',
#   'prediction': 'it must be true'},
#  {'label': 'jared', 'prediction': 'Adam'},
#  {'label': 'Jared', 'prediction': 'Adam'},
#  {'label': 'they are practicing', 'prediction': 'practicing a lot'},
#  {'label': 'A lot and', 'prediction': 'every day'},
#  {'label': 'a lot', 'prediction': 'every day'},
#  {'label': 'His birthday', 'prediction': 'his ninth birthday'},
#  {'label': 'his birthday', 'prediction': 'his ninth birthday'},
#  {'label': 'Max', 'prediction': 'Alex and Brady'},
#  {'label': 'Ty, and Max', 'prediction': 'Alex and Brady'},
#  {'label': 'Josh, Ty, and Max', 'prediction': 'Alex and Brady'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'The other dragons', 'prediction': 'Sean'},
#  {'label': 'The other dragons', 'prediction': 'Sean'},
#  {'label': 'Sarah', 'prediction': 'Wingate'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': "soon after eleven o'clock",
#   'prediction': 'On the following evening'},
#  {'label': 'during the brief pause', 'prediction': 'After Wingate left'},
#  {'label': 'brief pause', 'prediction': 'After Wingate left'},
#  {'label': 'a brief pause', 'prediction': 'After Wingate left'},
#  {'label': 'during a brief pause', 'prediction': 'After Wingate left'},
#  {'label': 'at least half a sovereign',
#   'prediction': 'half a sovereign every time'},
#  {'label': 'It depends', 'prediction': 'Jimmy'},
#  {'label': 'ham and pâté-de-foie-gras', 'prediction': 'sandwiches'},
#  {'label': '-ham and pâté-de-foie-gras', 'prediction': 'sandwiches'},
#  {'label': 'pâté', 'prediction': 'sandwiches'},
#  {'label': 'the 16th', 'prediction': 'May'},
#  {'label': '16', 'prediction': 'May'},
#  {'label': 'Aloisius', 'prediction': 'Benedict'},
#  {'label': 'John Paul II', 'prediction': 'Pope Paul VI'},
#  {'label': 'Archbishop of Munich and Freising and Cardinal',
#   'prediction': 'theologian'},
#  {'label': 'priest', 'prediction': 'theologian'},
#  {'label': 'Archbishop', 'prediction': 'theologian'},
#  {'label': 'Dean of the College of Cardinals', 'prediction': 'professor'},
#  {'label': 'Dean of the College of Cardinals', 'prediction': 'professor'},
#  {'label': 'theologian', 'prediction': 'professor'},
#  {'label': 'Eight', 'prediction': 'from 2005 until his resignation'},
#  {'label': '1927', 'prediction': '1951'},
#  {'label': 'Ratzinger;', 'prediction': 'Benedict'},
#  {'label': 'Ratzinger', 'prediction': 'Benedict'},
#  {'label': 'Wilbur Poole, Aaron Poole, and Nat Poole',
#   'prediction': 'Dave, Ben, and Phil'},
#  {'label': 'Aaron, Wilbur and Nat', 'prediction': 'Dave, Ben, and Phil'},
#  {'label': 'Wilbur, Aaron, and Nat', 'prediction': 'Dave, Ben, and Phil'},
#  {'label': 'Aaron Poole, Nat Poole, Wilbur Poole',
#   'prediction': 'Dave, Ben, and Phil'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'three people who had talked to him', 'prediction': 'a telegram'},
#  {'label': 'three people who had talked to the strange individual',
#   'prediction': 'a telegram'},
#  {'label': 'They met three people who had talked to the strange individual',
#   'prediction': 'a telegram'},
#  {'label': 'when it was getting late', 'prediction': 'tomorrow'},
#  {'label': 'when it got late', 'prediction': 'tomorrow'},
#  {'label': 'when it was getting late', 'prediction': 'tomorrow'},
#  {'label': 'Phil', 'prediction': 'Dave'},
#  {'label': 'it was getting late', 'prediction': "He's tired out"},
#  {'label': 'he is tired out', 'prediction': "He's tired out"},
#  {'label': 'he was tired out', 'prediction': "He's tired out"},
#  {'label': 'hit the trail for Bear Camp', 'prediction': 'give up'},
#  {'label': 'reach Carpen Falls', 'prediction': 'give up'},
#  {'label': 'they are going to Carpen Falls', 'prediction': 'give up'},
#  {'label': 'ride to Carpen Falls', 'prediction': 'give up'},
#  {'label': 'hit the trail for Bear Camp', 'prediction': 'have a look around'},
#  {'label': 'adolescence',
#   'prediction': 'information from various perspectives'},
#  {'label': 'Puberty', 'prediction': 'information from various perspectives'},
#  {'label': 'puberty', 'prediction': 'hormones'},
#  {'label': 'Puberty', 'prediction': 'hormones'},
#  {'label': 'n hormone production,',
#   'prediction': 'secondary sex characteristics'},
#  {'label': "or example, a deeper voice and larger adam's apple in boy",
#   'prediction': 'pituitary gland'},
#  {'label': "a deeper voice and larger adam's apple in boys",
#   'prediction': 'pituitary gland'},
# ...
#  {'label': 'horses', 'prediction': 'slowly'},
#  {'label': 'Palestinian territories', 'prediction': 'Palestine'},
#  {'label': 'Paletine', 'prediction': 'Palestine'},
#  {'label': "They carried out Gaza's first organ transplants",
#   'prediction': 'kidney transplants'},
#  {'label': "carried out Gaza's first organ transplants",
#   'prediction': 'kidney transplants'},
#  {'label': 'organ transplants', 'prediction': 'kidney transplants'},
#  {'label': 'Mohammed Duhair and Ziad Matouk',
#   'prediction': 'Mohammed Duhair, 42, received a kidney donated by his younger brother in a six-hour operation Two days later, Matouk received a transplant after his wife, Nadia, 36, was found to be a good match'},
#  {'label': 'Ziad Matouk and Mohammed Duhair',
#   'prediction': 'Mohammed Duhair, 42, received a kidney donated by his younger brother in a six-hour operation Two days later, Matouk received a transplant after his wife, Nadia, 36, was found to be a good match'},
#  {'label': 'last month', 'prediction': 'a fortnight ago'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': 'Worked hard', 'prediction': 'He built a house'},
#  {'label': 'he made a cave', 'prediction': 'He built a house'},
#  {'label': 'worked hard', 'prediction': 'He built a house'},
#  {'label': 'used his hands to work hard!', 'prediction': 'He built a house'},
#  {'label': 'Ye', 'prediction': 'No'},
#  {'label': 'In the end, he could enjoy the life', 'prediction': 'No'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': "He became Robinson's servant", 'prediction': 'A servant'},
#  {'label': 'teaching him to become a good servant', 'prediction': 'A servant'},
#  {'label': 'use our own hands to work hard with confidence',
#   'prediction': 'Robinson Crusoe hates the comfortable life in his home town'},
#  {'label': 'Use your own hands to work hard',
#   'prediction': 'Robinson Crusoe hates the comfortable life in his home town'},
#  {'label': 'We should use our own hands to work hard',
#   'prediction': 'Robinson Crusoe hates the comfortable life in his home town'},
#  {'label': 'in the saying all roads lead to Rome!',
#   'prediction': 'Robinson Crusoe hated the comfortable life in his home town'},
#  {'label': 'In a saying',
#   'prediction': 'Robinson Crusoe hated the comfortable life in his home town'},
#  {'label': 'all roads lead to Rome',
#   'prediction': 'Robinson Crusoe hated the comfortable life in his home town'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'Indian club'},
#  {'label': 'a club', 'prediction': 'Indian club'},
#  {'label': 'Young gymnast', 'prediction': 'Leo'},
#  {'label': 'it was  savage', 'prediction': 'A savage blow'},
#  {'label': 'Leo would have been severely injured',
#   'prediction': 'a severe injury'},
#  {'label': 'leo', 'prediction': 'Jack Snipper'},
#  {'label': 'Leo', 'prediction': 'Jack Snipper'},
#  {'label': 'Snipper', 'prediction': 'Jack'},
#  {'label': 'Snipper,', 'prediction': 'Jack'},
#  {'label': 'he dodged', 'prediction': 'swung the Indian club over his head'},
#  {'label': 'He dodged', 'prediction': 'swung the Indian club over his head'},
#  {'label': 'dodged', 'prediction': 'swung the Indian club over his head'},
#  {'label': 'Leo dodged', 'prediction': 'swung the Indian club over his head'},
#  {'label': 'quick', 'prediction': 'No'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': '“What harm has he done?”',
#   'prediction': 'What did Jack Snipper do?'},
#  {'label': '“Do you want to kill the boy?”',
#   'prediction': 'What did Jack Snipper do?'},
#  {'label': '“Do you want to kill the boy?',
#   'prediction': 'He was going to teach the boy a lesson'},
#  {'label': 'yes', 'prediction': 'He was going to teach the boy a lesson'},
#  {'label': '“What harm has he done?”',
#   'prediction': 'He was going to teach the boy a lesson'},
#  {'label': '“Do you want to kill the boy?”',
#   'prediction': 'He was going to teach the boy a lesson'},
#  {'label': 'Maddened', 'prediction': 'He’s going to teach the boy a lesson!'},
#  {'label': 'maddened', 'prediction': 'He’s going to teach the boy a lesson!'},
#  {'label': 'In the face', 'prediction': 'the empty air'},
#  {'label': 'face', 'prediction': 'the empty air'},
#  {'label': 'in the face', 'prediction': 'the empty air'},
#  {'label': 'everyone walked away',
#   'prediction': 'all the performers walked away'},
#  {'label': 'nearly 49 million artists', 'prediction': 'over 1 million'},
#  {'label': '49 million', 'prediction': 'over 1 million'},
#  {'label': '49 million artists', 'prediction': 'over 1 million'},
#  {'label': 'over 1 million labels',
#   'prediction': 'nearly 346,000 contributor user accounts'},
#  {'label': '1 million',
#   'prediction': 'nearly 346,000 contributor user accounts'},
#  {'label': 'Kevin Lewandowski', 'prediction': 'DJ'},
#  {'label': 'The success of Slashdot, eBay, and Open Directory Project',
#   'prediction': 'community-built sites'},
#  {'label': 'Slashdot, eBay, and Open Directory Project',
#   'prediction': 'community-built sites'},
#  {'label': 'in January 2004', 'prediction': 'in 2003'},
#  {'label': 'January 2004', 'prediction': 'in 2003'},
#  {'label': 'capture of virtually every single type of audio recording that has ever been released',
#   'prediction': 'to build the most comprehensive database of electronic music'},
#  {'label': 'to build the most comprehensive database of music',
#   'prediction': 'to build the most comprehensive database of electronic music'},
#  {'label': 'Capture every single type of audio recording that has ever been released',
#   'prediction': 'to build the most comprehensive database of electronic music'},
#  {'label': 'capture of virtually every single type of audio recording',
#   'prediction': 'to build the most comprehensive database of electronic music'},
#  {'label': 'Meditation-practice', 'prediction': 'ogachara'},
#  {'label': 'Buddha-nature', 'prediction': 'ogachara'},
#  {'label': 'rigorous self-control', 'prediction': 'ogachara'},
#  {'label': 'rigorous self-control', 'prediction': 'nsight into Buddha-nature'},
#  {'label': 'Rigorous self-control', 'prediction': 'nsight into Buddha-nature'},
#  {'label': "Insight into Buddha's nature",
#   'prediction': 'nsight into Buddha-nature'},
#  {'label': 'Direct understanding',
#   'prediction': 'irect understanding through zazen and interaction with an accomplished teacher'},
#  {'label': 'direct understanding',
#   'prediction': 'irect understanding through zazen and interaction with an accomplished teacher'},
#  {'label': 'Chan', 'prediction': 'hyāna'},
#  {'label': 'Indian', 'prediction': 'han Buddhism'},
#  {'label': 'Indians', 'prediction': 'han Buddhism'},
#  {'label': 'unknown', 'prediction': 'es'},
#  {'label': 'no', 'prediction': 'es'},
#  {'label': '禪 (Chan)', 'prediction': 'han Buddhism'},
#  {'label': 'Japanese Zen', 'prediction': 'han Buddhism'},
#  {'label': 'Ferdinand II', 'prediction': "D'Aubigny"},
#  {'label': 'the French general', 'prediction': 'Viceroy'},
#  {'label': 'the following year', 'prediction': 'in Pozzuoli'},
#  {'label': 'the following year', 'prediction': 'in Pozzuoli'},
#  {'label': 'an army', 'prediction': 'the House of Aragon'},
#  {'label': 'army', 'prediction': 'the House of Aragon'},
#  {'label': 'Ferdinand and Isabella', 'prediction': 'the House of Aragon'},
#  {'label': "Ferdinand and Isabella's", 'prediction': 'the House of Aragon'},
#  {'label': "Ferdinand's and Isabella's", 'prediction': 'the House of Aragon'},
#  {'label': 'Doña Sancia of Aragon', 'prediction': 'Giovanni Sforza'},
#  {'label': 'Doña Sancia', 'prediction': 'Giovanni Sforza'},
#  {'label': 'Giuffredo Borgia', 'prediction': 'Doña Sancia'},
#  {'label': 'Marquis Gonzaga of Mantua', 'prediction': 'the Spaniards'},
#  {'label': 'Marquis Gonzaga', 'prediction': 'the Spaniards'},
#  {'label': 'in Norfolk', 'prediction': 'Norfolk, England'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Three', 'prediction': '3'},
#  {'label': 'Inge Crane', 'prediction': 'her parents'},
#  {'label': 'a nanny', 'prediction': 'her parents'},
#  {'label': 'Mary Clarke', 'prediction': 'her parents'},
#  {'label': 'Princes Andrew and Edward', 'prediction': 'the butler'},
#  {'label': 'going outdoors, climbing trees and playing with animals',
#   'prediction': 'go outdoors'},
#  {'label': 'going outdoors, climbing trees and playing with animals',
#   'prediction': 'go outdoors'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'the back yard', 'prediction': 'to reach the chicken pen'},
#  {'label': 'so that her father could make scrambled eggs',
#   'prediction': 'to make scrambled eggs for breakfast'},
#  {'label': 'so her father could make scrambled eggs',
#   'prediction': 'to make scrambled eggs for breakfast'},
#  {'label': 'So that her father could make scrambled eggs',
#   'prediction': 'to make scrambled eggs for breakfast'},
#  {'label': 'Five', 'prediction': 'at least 5'},
#  {'label': 'a nest', 'prediction': 'eggs'},
#  {'label': 'A nest', 'prediction': 'eggs'},
#  {'label': 'an egg', 'prediction': 'eggs'},
#  {'label': 'yes', 'prediction': 'eggs'},
#  {'label': 'Yes', 'prediction': 'eggs'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'Being stupid', 'prediction': 'for having been so stupid'},
#  {'label': "call at Mrs Byram's", 'prediction': 'congratulate him'},
#  {'label': "to call at Mrs Byram's", 'prediction': 'congratulate him'},
#  {'label': 'To call', 'prediction': 'congratulate him'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'No', 'prediction': 'yes'},
#  {'label': 'Bill', 'prediction': 'Fred and the miners'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'to do whatever he believed their interests demanded',
#   'prediction': 'his clients relative'},
#  {'label': 'full authority', 'prediction': 'his clients relative'},
#  {'label': 'With full authority', 'prediction': 'his clients relative'},
#  {'label': 'with full authority', 'prediction': 'his clients relative'},
#  {'label': 'The cashier', 'prediction': 'Donovan'},
#  {'label': 'He wanted to help the poor students', 'prediction': 'to the city'},
#  {'label': 'He wanted to help the poor students', 'prediction': 'to the city'},
#  {'label': "to pay the fee for the city's sports",
#   'prediction': 'to the city'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'yes', 'prediction': 'no'},
#  {'label': 'Yes', 'prediction': 'no'},
#  {'label': 'Ryan Reynolds Sandra Bullock,',
#   'prediction': 'Ryan Reynolds and Sandra Bullock'},
#  {'label': 'Ryan Reynolds & Sandra Bullock',
#   'prediction': 'Ryan Reynolds and Sandra Bullock'},
#  {'label': 'no', 'prediction': 'yes'},
#  {'label': 'No', 'prediction': 'yes'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': ', Margaret,', 'prediction': 'Sandra Bullock'},
#  {'label': 'Margaret,', 'prediction': 'Sandra Bullock'},
#  {'label': 'Margaret', 'prediction': 'Sandra Bullock'},
#  {'label': 'Boss', 'prediction': 'senior'},
#  {'label': 'book editor', 'prediction': 'senior'},
#  {'label': 'Amusing complications ensue',
#   'prediction': 'Sandra Bullock is the shrew, Margaret, a pitiless, high-powered New York book editor first seen multitasking in the midst of her aerobic workout'},
#  {'label': 'The chemical energy between Bullock and Reynolds is fresh and irresistible',
#   'prediction': 'Sandra Bullock is the shrew, Margaret, a pitiless, high-powered New York book editor first seen multitasking in the midst of her aerobic workout'},
#  {'label': 'Margaret, with her visa expired, faces deportation',
#   'prediction': 'Sandra Bullock is the shrew, Margaret, a pitiless, high-powered New York book editor first seen multitasking in the midst of her aerobic workout'},
#  {'label': 'She marries Andrew to avoid deportation',
#   'prediction': 'Sandra Bullock is the shrew, Margaret, a pitiless, high-powered New York book editor first seen multitasking in the midst of her aerobic workout'},
#  {'label': 'she marries Andrew in a green-card wedding',
#   'prediction': 'marry him'},
#  {'label': 'She decides to marry Andrew', 'prediction': 'marry him'},
#  {'label': 'Margaret decision to marry Andrew i', 'prediction': 'marry him'},
#  {'label': 'marrying Andrew', 'prediction': 'marry him'},
#  {'label': 'greencard', 'prediction': 'a green-card wedding'},
#  {'label': "visit to the groom-to-be's family i", 'prediction': 'Alaska'},
#  {'label': "the groom-to-be's family", 'prediction': 'yes'},
#  {'label': "groom-to-be's family", 'prediction': 'yes'},
#  {'label': "the groom-to-be's family", 'prediction': 'Bullock and Reynolds'},
#  {'label': "groom-to-be's family in Alaska",
#   'prediction': 'Bullock and Reynolds'},
#  {'label': "The groom-to-be's family", 'prediction': 'Bullock and Reynolds'},
#  {'label': "a visit to the groom-to-be's family i",
#   'prediction': 'Bullock and Reynolds'},
#  {'label': 'unknown', 'prediction': 'Yes'},
#  {'label': 'no', 'prediction': 'Yes'},
#  {'label': 'No', 'prediction': 'Yes'},
#  {'label': "Shakespeare's 1590s", 'prediction': "the 1940s and '50s"},
#  {'label': 'It stands for Height about average terrain',
#   'prediction': 'eight above average terrain'},
#  {'label': 'no', 'prediction': 'es'},
#  {'label': 'Usually in the mountainous regions', 'prediction': 'ountains'},
#  {'label': 'Mountainous regions', 'prediction': 'ountains'},
#  {'label': 'in a valley', 'prediction': 'ountains'},
#  {'label': 'VHF and UHF', 'prediction': 'M radio and television'},
#  {'label': 'Usually VHF and UHF', 'prediction': 'M radio and television'},
#  {'label': 'meters', 'prediction': 'he antenna'},
#  {'label': 'Meters', 'prediction': 'he antenna'},
#  {'label': 'radials', 'prediction': 'he antenna'},
#  {'label': 'Stations can be received on either side of the international boundaries',
#   'prediction': 't is more important than effective radiated power'},
#  {'label': 'For international coordination',
#   'prediction': 't is more important than effective radiated power'},
#  {'label': 'extensive border zones where stations can be received on either side of the international boundaries',
#   'prediction': 't is more important than effective radiated power'},
#  {'label': 'So that stations can be recieved on either side of the international boundaries',
#   'prediction': 't is more important than effective radiated power'},
#  {'label': 'The altitude of the antenna site, minus the average altitude of all the specified points',
#   'prediction': 'he maximum distance their station class is allowed to cover'},
#  {'label': 'average altitude',
#   'prediction': 'he maximum distance their station class is allowed to cover'},
#  {'label': 'Altitude of the antenna site, minus the average altitude of all the specified points',
#   'prediction': 'he maximum distance their station class is allowed to cover'},
#  {'label': 'a group of teenagers', 'prediction': 'unknown'},
#  {'label': 'yes', 'prediction': 'unknown'},
#  {'label': 'allegedly a group of teenagers', 'prediction': 'unknown'},
#  {'label': 'Yes', 'prediction': 'unknown'},
#  {'label': 'yes', 'prediction': 'No'},
#  {'label': 'Yes', 'prediction': 'No'},
#  {'label': 'a lifelong recovery', 'prediction': 'unknown'},
#  {'label': 'lifelong', 'prediction': 'unknown'},
#  {'label': 'He has a lifelong recoery', 'prediction': 'unknown'},
#  {'label': 'he faces a lifelong recovery', 'prediction': 'unknown'},
#  {'label': 'mother and father', 'prediction': 'They are both parents'},
#  {'label': 'his parents', 'prediction': 'They are both parents'},
#  {'label': 'His parents', 'prediction': 'They are both parents'},
#  {'label': 'Guarded', 'prediction': 'Burned over 65 percent of his body'},
#  {'label': 'guarded condition',
#   'prediction': 'Burned over 65 percent of his body'},
#  {'label': 'guarded', 'prediction': 'Burned over 65 percent of his body'},
#  {'label': 'second- and third-degree', 'prediction': 'Twice'},
#  {'label': 'second- and third-degree burns', 'prediction': 'Twice'},
#  {'label': '2nd and 3rd degree burns', 'prediction': 'Twice'},
#  ...]

# %% [markdown]
# ### Best result with best_answers=3
